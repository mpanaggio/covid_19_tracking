# %% [markdown]
# # Instructions
# 1. Click "Restart and run all" from the kernel menu to run the notebook.
#
# 2. Then change the state as needed by making your selections in the menu below. You can use "Shift" or "Ctrl" to select multiple countries.
#
# 3. Then select the cell that starts with "% matplotlib notebook" and press "Shift + Enter" to update the plot.
#
# 4. The curves are exponential functions fit to a range of data for each state.  You can adjust the range of data points used to fit these curves using the textboxes.  The estimated numbers of cases on the indicated day based on those exponential models will be printed below.
#
# Note: You can display nationwide totals by selecting "All" from the state menu. Keep in mind that the models are fit independently so the predictions for a single country may even exceed the predictions for all if the current growth rate is high.

# %%
from covid_plotting_tools_state import *
select,states=create_selection_box()

# %% [markdown]
# After making your selection above, select the cell below and hit "Run" or press "Shift"+ "Enter" to update the plot.

# %%
# %matplotlib notebook
from ipywidgets import interact, interactive, fixed, interact_manual
last_month,last_day,maxval,state,df_dict=compute_data_props(states,select)
#print(last_month,last_day,maxval)
out,ui,lines,lstart,lend=make_interactive_plot(end_month_plot=last_month,end_day_plot=last_day,
                                               def_end_month_fit=last_month,def_end_day_fit=last_day,
                                               def_month_pred=last_month,def_day_pred=last_day,
                                              maxval=maxval,country=state,df_dict=df_dict)
display(ui,out)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# GridBox(children=(FloatRangeSlider(value=(-0.1, 1.1), description='x range', max=1.5, min=-0.2, readout=False,…
# Output()

# %% [markdown]
# Note: An exponential model may not be appropriate for describing the spread of COVID-19 in every state. The data points will follow a linear trend when the y-axis is logarithmic if an exponential model is appropriate.  If the datapoints fall below the fit line on the right side of the plot, then that suggests that the growth is slower than exponential.
